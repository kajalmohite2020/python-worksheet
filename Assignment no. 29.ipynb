# %%
#Assignment no.29
#1.Write a Python program to find the unique employee IDs in a company.
employe_ids=[101, 102, 103, 101, 104, 102, 105]
unique=set(employe_ids)
print("unique employee IDs in a company are:", unique)
# Out:
# unique employee IDs in a company are: {101, 102, 103, 104, 105}

# %%
#2.Write a Python program to find the common departments between two companies.
company1 = ["HR", "Finance", "Marketing", "IT", "Sales","Admin"]
company2 = ["Admin", "IT", "Finance", "Support", "Sales"]
common =(set(company1) and set(company2))  
print("Common Departments between two companies are:",common)
# Out:
# Common Departments between two companies are: {'Sales', 'Support', 'Admin', 'IT', 'Finance'}

# %%
#3. Write a Python program to remove duplicate employee names from a list.
employee_names = ["amit", "sita", "ravi", "shravani", "sita", "yash", "shravani"]
duplicate_name = set(employee_names)
print("Remove duplicate employee names are:",duplicate_name)
# Out:
# Remove duplicate employee names are: {'amit', 'shravani', 'yash', 'sita', 'ravi'}

# %%
#4.Write a Python program to find the unique guests invited to a party.
guests = ["Asha", "Rohan", "Meera", "Asha", "Kabir", "Rohan"]
unique_guests = set(guests)
print("unique guests invited to a party:",unique_guests)
# Out:
# unique guests invited to a party: {'Rohan', 'Asha', 'Meera', 'Kabir'}

# %%
#5.Write a Python program to find the common attendees between two events.
events1 = ["Asha", "Rohan", "Meera", "sita", "Kabir", "ravi"]
events2 = ["amit", "sita", "ravi", "shravani","Asha", "yash",]
common =set(events1) & set(events2) 
print(" common attendees between two events:", common)
# Out:
#  common attendees between two events: {'Asha', 'sita', 'ravi'}

# %%
#6.Write a Python program to remove duplicate event dates from a calendar.
event_dates = ["01-01-2025","02-10-2024", "01-01-2025", "02-10-2024"]
duplicate_dates = set(event_dates)
print("duplicate event dates from a calendar are:",duplicate_dates)
# Out:
# duplicate event dates from a calendar are: {'02-10-2024', '01-01-2025'}

# %%
#7.Write a Python program to find the unique product codes in an inventory.
product_codes = ["P101", "P202", "P303", "P101", "P404", "P202"]
unique_codes = set(product_codes)
print("unique product codes in an inventory:",unique_codes)
# Out:
# unique product codes in an inventory: {'P202', 'P404', 'P101', 'P303'}

# %%
#8.Write a Python program to find the common products between two warehouses.
warehouse1 = ["P101", "P202", "P303", "P404"]
warehouse2 = ["P202", "P404", "P505", "P606"]
common = set(warehouse1) & set(warehouse2) 
print("common products between two warehouses are:",common)
# Out:
# common products between two warehouses are: {'P202', 'P404'}

# %%
#9.Write a Python program to remove duplicate product names from a catalog.
catalogue = ["Soap", "Shampoo", "Toothpaste", "Soap","Oil", "Shampoo", "Cream"]
duplicate_name = set(catalogue)
print("duplicate product names from a catalog are:",duplicate_name)
# Out:
# duplicate product names from a catalog are: {'Soap', 'Oil', 'Toothpaste', 'Shampoo', 'Cream'}

# %%
#10.Write a Python program to find the unique student IDs in a school.
student_ids = [101, 202, 303, 101, 404, 202, 505]
unique_IDs = set(student_ids)
print("unique student IDs in a school is are:",unique_IDs)
# Out:
# unique student IDs in a school is are: {101, 202, 303, 404, 505}

# %%
#11.Write a Python program to find the common courses between two students.
student1 = ["Data Science", "Data Analytics", "Machine Learning", "AI", "Big Data"]
student2 = ["Data Science", "Data Analytics", "Deep Learning", "AI", "Cloud Computing"]
common = set(student1) & set(student2)
print("common courses between two students are:",common)
# Out:
# common courses between two students are: {'Data Analytics', 'AI', 'Data Science'}

# %%
#12.Write a Python program to remove duplicate student names from a roster.
students = ["Amit", "Riya", "Sohan", "Neha", "Aarav", "Pooja","Amit","Sohan"]
duplicate_name = set(students)
print("student names from a roster are:",duplicate_name)
# Out:
# student names from a roster are: {'Sohan', 'Riya', 'Aarav', 'Pooja', 'Amit', 'Neha'}

# %%
#13.Write a Python program to find the unique songs in a playlist.
playlist = ["SongA", "SongB", "SongC", "SongA", "SongD", "SongB", "SongE"]
unique_song = set(playlist)
print("unique songs in a playlist are:",unique_song)
# Out:
# unique songs in a playlist are: {'SongB', 'SongE', 'SongA', 'SongD', 'SongC'}

# %%
#14.Write a Python program to find the common artists between two music libraries.
library1 = ["ArtistA", "ArtistB", "ArtistC", "ArtistD"]
library2 = ["ArtistC", "ArtistD", "ArtistE", "ArtistF"]
common = set(library1) & set(library2)
print("common artists between two music libraries are :",common)
# Out:
# common artists between two music libraries are : {'ArtistC', 'ArtistD'}

# %%
#15. Write a Python program to remove duplicate albums from a music collection.
albums = ["Thriller", "Back in Black", "Thriller", "Hotel California","Rumours", "Back in Black", "Purple Rain"]
duplicate_albums = set(albums)
print(" duplicate albums from a music collection are:",duplicate_albums)
# Out:
#  duplicate albums from a music collection are: {'Thriller', 'Rumours', 'Hotel California', 'Purple Rain', 'Back in Black'}

# %%
#16. Write a Python program to find the unique movies in a watchlist.
watch_list = ["Inception", "Avatar", "Inception", "Titanic", "Avengers", "Titanic"]
unique_movies = set(watch_list)
print("unique movies in a watchlist:",unique_movies)
# Out:
# unique movies in a watchlist: {'Avatar', 'Inception', 'Titanic', 'Avengers'}

# %%
#17.Write a Python program to find the common actors between two movies.
movie1_actors = ["actor1", "actor2", "actor3", "actor4"]
movie2_actors = ["actor1", "actor2", "actor5", "actor6"]
common = set(movie1_actors) & set(movie2_actors)
print("common actors between two movies are:",common)
# Out:
# common actors between two movies are: {'actor1', 'actor2'}

# %%
#18.Write a Python program to remove duplicate movie titles from a list.
movies = ["Inception", "Avatar", "Titanic", "Inception", "Avengers", "Titanic"]
duplicate_titles =set(movies)
print("duplicate movie titles from a list:",duplicate_titles)
# Out:
# duplicate movie titles from a list: {'Avatar', 'Inception', 'Titanic', 'Avengers'}

# %%
#19.Write a Python program to find the unique teams in a league.
teams = ["TeamA", "TeamB", "TeamC", "TeamA", "TeamD", "TeamB"]
unique_teams = set(teams)
print("unique teams in a league are:",unique_teams)
# Out:
# unique teams in a league are: {'TeamB', 'TeamC', 'TeamD', 'TeamA'}

# %%
#20.Write a Python program to find the common players between two teams.
team1_players = ["player1", "player2", "player3", "player4"]
team2_players = ["player3", "player4", "player5", "player6"]
common_players = set(team1_players) & set(team2_players)
print("common players between two teams are:",common_players)
# Out:
# common players between two teams are: {'player3', 'player4'}

# %%
#21. Write a Python program to remove duplicate player IDs from a roster.
player_ids = [101, 102, 103, 101, 104, 102, 105]
duplicate_IDs = set(player_ids)
print("duplicate player IDs from a roster are:",duplicate_IDs)
# Out:
# duplicate player IDs from a roster are: {101, 102, 103, 104, 105}

# %%
#22.Write a Python program to find the unique authors in a library.
authors = ["Author1", "Author2", "Author3", "Author1", "Author4", "Author2"]
unique_authors = set(authors)
print("unique authors in a library:",unique_authors)
# Out:
# unique authors in a library: {'Author4', 'Author3', 'Author2', 'Author1'}

# %%
#23.Write a Python program to find the common books between two shelves.
shelf1 = ["book1", "book2", "book3", "book4"]
shelf2 = ["book3", "book4", "book5", "book6"]
common_books = set(shelf1) & set(shelf2)
print("common books between two shelves are:",common_books)
# Out:
# common books between two shelves are: {'book4', 'book3'}

# %%
#24. Write a Python program to remove duplicate book titles from a catalog.
catalogue = ["BookA", "BookB", "BookC", "BookA", "BookD", "BookB"]
duplicate_titles = set(catalogue)
print("duplicate book titles from a catalog are:",duplicate_titles)
# Out:
# duplicate book titles from a catalog are: {'BookB', 'BookD', 'BookC', 'BookA'}
